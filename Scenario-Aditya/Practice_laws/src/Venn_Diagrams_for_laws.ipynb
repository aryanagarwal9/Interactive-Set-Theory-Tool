# %% [markdown]
# # Venn Diagrams for Laws

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2_unweighted, venn3_unweighted

# %%
A = set()
B = set()
C = set()

# %% [markdown]
# # A

# %%
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#3598ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#aed7ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("A", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A')

# %% [markdown]
# # B

# %%
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#3598ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#aed7ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("B", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'B')

# %% [markdown]
# # C

# %%
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#3598ff")
diagram.get_patch_by_id("110").set_color("#aed7ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("C", x=0.5, y=-0.2, fontsize=20)
plt.show()

# %% [markdown]
# ## A|B

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#3598ff")
diagram.get_patch_by_id("010").set_color("#3598ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("AUB", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'AUB')

# %% [markdown]
# ## A&B

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#aed7ff")
diagram.get_patch_by_id("011").set_color("#aed7ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("A∩B", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A∩B')

# %% [markdown]
# ## BIC

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#3598ff")
diagram.get_patch_by_id("001").set_color("#3598ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("BUC", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'BUC')

# %% [markdown]
# ## B&C

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#aed7ff")
diagram.get_patch_by_id("101").set_color("#aed7ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("B∩C", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'B∩C')

# %% [markdown]
# ## A|C

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#3598ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#3598ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("AUC", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'AUC')

# %% [markdown]
# ## A&C

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#aed7ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#aed7ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("A∩C", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A∩C')

# %% [markdown]
# ## (A|B) | C and A | (B|C)

# %%
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#3598ff")
diagram.get_patch_by_id("010").set_color("#3598ff")
diagram.get_patch_by_id("001").set_color("#3598ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("(AUB)UC and AU(BUC)", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, '(AUB)UC and AU(BUC)')

# %% [markdown]
# ## (A&B) & C and A & (B&C)

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#aed7ff")
diagram.get_patch_by_id("101").set_color("#aed7ff")
diagram.get_patch_by_id("011").set_color("#aed7ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("(A∩B)∩C and A∩(B∩C)", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, '(A∩B)∩C and A∩(B∩C)')

# %% [markdown]
# ## A | (B&C) and (A|B) & (A|C)

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#3598ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#3598ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("AU(B∩C) and (AUB)∩(AUC)", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'AU(B∩C) and (AUB)∩(AUC)')

# %% [markdown]
# ## A & (B|C) and (A&B) | (A&C)

# %%
#aed7ff, #3598ff
diagram = venn3_unweighted([A,B,C], set_labels = ("A", "B", "C"))
diagram.get_label_by_id("100").set_text("")
diagram.get_label_by_id("010").set_text("")
diagram.get_label_by_id("001").set_text("")
diagram.get_label_by_id("110").set_text("")
diagram.get_label_by_id("101").set_text("")
diagram.get_label_by_id("011").set_text("")
diagram.get_label_by_id("111").set_text("")
diagram.get_patch_by_id("100").set_color("#aed7ff")
diagram.get_patch_by_id("010").set_color("#aed7ff")
diagram.get_patch_by_id("001").set_color("#aed7ff")
diagram.get_patch_by_id("110").set_color("#3598ff")
diagram.get_patch_by_id("101").set_color("#3598ff")
diagram.get_patch_by_id("011").set_color("#aed7ff")
diagram.get_patch_by_id("111").set_color("#3598ff")
plt.title("A∩(BUC) and (A∩B)U(A∩C)", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A∩(BUC) and (A∩B)U(A∩C)')

# %% [markdown]
# ## A & (A|B) and A | (A&B)

# %%
#aed7ff, #3598ff
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#3598ff")
diagram.get_patch_by_id("01").set_color("#aed7ff")
diagram.get_patch_by_id("11").set_color("#3598ff")
plt.title("A∩(AUB) and AU(A∩B)", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A∩(AUB) and AU(A∩B)')

# %% [markdown]
# ## A'

# %%
#aed7ff, #3598ff
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#aed7ff")
diagram.get_patch_by_id("01").set_color("#3598ff")
diagram.get_patch_by_id("11").set_color("#aed7ff")
plt.title("A'", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, "A'")

# %% [markdown]
# ## B'

# %%
#aed7ff, #3598ff
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#3598ff")
diagram.get_patch_by_id("01").set_color("#aed7ff")
diagram.get_patch_by_id("11").set_color("#aed7ff")
plt.title("B'", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, "B'")

# %% [markdown]
# ## A'&B' and (A|B)'

# %%
#aed7ff, #3598ff
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#aed7ff")
diagram.get_patch_by_id("01").set_color("#aed7ff")
diagram.get_patch_by_id("11").set_color("#aed7ff")
plt.title("A'∩B' and (AUB)'", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, "A'∩B' and (AUB)'")

# %% [markdown]
# ## (A&B)' and A'|B'

# %%
#aed7ff, #3598ff
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#3598ff")
diagram.get_patch_by_id("01").set_color("#3598ff")
diagram.get_patch_by_id("11").set_color("#aed7ff")
plt.title("(A∩B)' and A'UB'", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, "(A∩B)' and A'UB'")

# %%
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#3598ff")
diagram.get_patch_by_id("01").set_color("#3598ff")
diagram.get_patch_by_id("11").set_color("#3598ff")
plt.title("AUB", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'AUB')

# %%
diagram = venn2_unweighted([A,B], set_labels = ("A", "B"))
diagram.get_label_by_id("10").set_text("")
diagram.get_label_by_id("01").set_text("")
diagram.get_label_by_id("11").set_text("")
diagram.get_patch_by_id("10").set_color("#aed7ff")
diagram.get_patch_by_id("01").set_color("#aed7ff")
diagram.get_patch_by_id("11").set_color("#3598ff")
plt.title("A∩B", x=0.5, y=-0.2, fontsize=20)
# Out:
# Text(0.5, -0.2, 'A∩B')
